# %% [markdown]
# <a href="https://colab.research.google.com/github/Smccb/Data_Analytics_lab1/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('titanic.csv', sep=';')
data.head()
# Out:
#   survived  pclass                                               name     sex  \
# 0       No     3.0                            Braund, Mr. Owen Harris    male
# 1      Yes     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2      Yes     3.0                             Heikkinen, Miss. Laina  female
# 3      Yes     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       No     3.0                           Allen, Mr. William Henry    male
#
#     age            ticket     fare embarked
# 0  22.0         A/5 21171   7.2500        S
# 1  38.0          PC 17599  71.2833        C
# 2  26.0  STON/O2. 3101282   7.9250        S
# 3  35.0            113803  53.1000        S
# 4  35.0            373450   8.0500        S

# %%
data.sample(10)
# Out:
#     survived  pclass                             name     sex   age  \
# 475       No     1.0      Clifford, Mr. George Quincy    male   NaN
# 767       No     3.0               Mangan, Miss. Mary  female  30.5
# 654       No     3.0     Hegarty, Miss. Hanora 'Nora'  female  18.0
# 458      Yes     2.0              Toomey, Miss. Ellen  female  50.0
# 386       No     3.0  Goodwin, Master. Sidney Leonard    male   1.0
# 69        No     3.0                Kink, Mr. Vincenz    male  26.0
# 712      Yes     1.0         Taylor, Mr. Elmer Zebley    male  48.0
# 50        No     3.0       Panula, Master. Juha Niilo    male   7.0
# 310      Yes     1.0   Hays, Miss. Margaret Bechstein  female  24.0
# 544       No     1.0       Douglas, Mr. Walter Donald    male  50.0
#
#            ticket      fare embarked
# 475        110465   52.0000        S
# 767        364850    7.7500        Q
# 654        365226    6.7500        Q
# 458  F.C.C. 13531   10.5000        S
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    object
#  1   pclass    891 non-null    float64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   ticket    891 non-null    object
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 55.8+ KB

# %%
data.fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
data['embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: embarked, Length: 891, dtype: object

# %%
data['embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: embarked, dtype: object

# %%
data.embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
data.fare.hist()
# Out:
# <Axes: >

# %%
data.embarked.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age         177
# ticket        0
# fare          0
# embarked      2
# dtype: int64

# %%
data.isnull().sum()/len(data)
# Out:
# survived    0.000000
# pclass      0.000000
# name        0.000000
# sex         0.000000
# age         0.198653
# ticket      0.000000
# fare        0.000000
# embarked    0.002245
# dtype: float64

# %%
data.pclass = data.pclass.astype('object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    object
#  1   pclass    891 non-null    object
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   ticket    891 non-null    object
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 55.8+ KB

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64', 'int32']).describe()
numeric_data.describe()
# Out:
#               age        fare
# count    8.000000    8.000000
# mean   115.596327  192.323930
# std    242.905673  330.625663
# min      0.420000    0.000000
# 25%     18.725374   12.818250
# 50%     28.849559   31.602104
# 75%     48.500000  165.352371
# max    714.000000  891.000000

# %%
pd.plotting.scatter_matrix(numeric_data)
# Out:
# array([[<Axes: xlabel='age', ylabel='age'>,
#         <Axes: xlabel='fare', ylabel='age'>],
#        [<Axes: xlabel='age', ylabel='fare'>,
#         <Axes: xlabel='fare', ylabel='fare'>]], dtype=object)

# %%
object_data = data.select_dtypes(include=['object', 'category'])
object_data.describe()
# Out:
#        survived  pclass                     name   sex  ticket embarked
# count       891   891.0                      891   891     891      889
# unique        2     3.0                      891     2     681        3
# top          No     3.0  Braund, Mr. Owen Harris  male  347082        S
# freq        549   491.0                        1   577       7      644

# %%
data.survived.value_counts()
# Out:
# No     549
# Yes    342
# Name: survived, dtype: int64
